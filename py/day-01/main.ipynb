# %%
num1 =20
num2= -9
num3=0

print("num1",num1, type(num1))
print("num2",num2, type(num2))
print("num3",num3, type(num3))
# Out:
# num1 20 <class 'int'>
# num2 -9 <class 'int'>
# num3 0 <class 'int'>

# %%
num1 =20
num2= 2e2
num3=0

print("num1",num1, type(num1))
print("num2",num2, type(num2))
print("num3",num3, type(num3))
# Out:
# num1 20 <class 'int'>
# num2 200.0 <class 'float'>
# num3 0 <class 'int'>

# %%
num1 ="""HI i'm writing
multiline string"""

num2= 'hi python'
num3="hiiiiii, awx"

print("num1",num1, type(num1))
print("num2",num2, type(num2))
print("num3",num3, type(num3))
# Out:
# num1 HI i'm writing
# multiline string <class 'str'>
# num2 hi python <class 'str'>
# num3 hiiiiii, awx <class 'str'>

# %%
f_name="Ahmad"
l_name="Wahab"

full_name=f_name+" "+l_name+ " original"
repition=("\n"+f_name+" "+l_name+"\n")*3

print(full_name)
print(repition)
# Out:
# Ahmad Wahab original
#
# Ahmad Wahab
#
# Ahmad Wahab
#
# Ahmad Wahab

# %%
f_name="Ahmad"
l_name="Wahab"
full=f_name+l_name

f=full[0:5]
print(f)

f=full[0]
print(f)
# Out:
# Ahmad
# A

# %%
AGE=21

print(f"my age is {AGE}")
# Out:
# my age is 21

# %%
is_active=True
if is_active :
  print("ok")
# Out:
# ok

# %% [markdown]
# # **COLLECTIONS**

# %%
empty_list=[]
numbers=[1,2,40,60]
mixed_list=["awx",123,1.3,True]

print(empty_list)
print(numbers)
print(mixed_list)

num1=numbers[0]
num2=numbers[1]
lastnum=mixed_list[-1]
print(num1)
print(num2)
print(lastnum)
# Out:
# []
# [1, 2, 40, 60]
# ['awx', 123, 1.3, True]
# 1
# 2
# True
