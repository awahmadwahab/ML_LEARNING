# %% [markdown]
# **COMPARISON**

# %%
a,b=3,4
print("a>b",a>b)
print("a<b",a<b)
print("a==b",a==b)
print("a!=b",a!=b)
print("a>=b",a>=b)
print("a<=b",a<=b)
# Out:
# a>b False
# a<b True
# a==b False
# a!=b True
# a>=b False
# a<=b True
