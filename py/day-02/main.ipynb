# %% [markdown]
# # **Operators**

# %% [markdown]
#  **Assignment Operators**

# %%
x=5
x+=3
print(x)

# %% [markdown]
#  **Arithmetic Operators**

# %%
a,b=5,6

print(a,b)
print("sum",a+b)
print("difference",a-b)
print("product",a*b)
print("quotient",a/b)
print("floor division",a//b)
print("modulus",a%b)
print("power",a**b)
